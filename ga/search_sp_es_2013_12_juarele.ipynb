# %%
import json;

# %%
myperfjson = {"search_by_search_period":[{"id":"ES_m_2013-12_*-*","market":"ES","ptype":"m","period":"2013-12","onds":[{"origin":"*","destination":"*"}],"nb_req":2486502,"top_onds":[["MAD-NYC",45426,44735],["MAD-LON",32772,36962],["MAD-PAR",31422,28431],["BCN-NYC",23396,19974],["MAD-LIM",22431,15967],["MAD-ROM",21847,19966],["BCN-LON",20107,21889],["BCN-MAD",18762,25028],["BCN-PAR",18285,19923],["MAD-BCN",18282,18940],["MAD-BUE",17081,17481],["MAD-TCI",15918,20030],["MAD-BKK",15470,12605],["MAD-AMS",13235,15079],["MAD-MIA",12883,12638],["BCN-ROM",12122,11710],["MAD-BER",11457,12016],["MAD-BRU",11412,9735],["MAD-LPA",10742,20857],["MAD-RAK",10701,9326],["MAD-LIS",10467,10059],["MAD-SCL",9774,7281],["BCN-BUE",9738,8274],["BCN-BKK",9463,6655],["BCN-AMS",9060,9884],["MAD-MIL",9036,13365],["AGP-LON",8773,7269],["MAD-MEX",8721,9854],["MAD-PRG",8521,10030],["MAD-IST",8469,10568],["MAD-HAV",8454,6238],["MAD-BOG",8435,7222],["BCN-BER",8301,7887],["MAD-SAO",8295,5679],["BCN-TCI",8245,12463],["MAD-SDQ",8079,7858],["MAD-UIO",7731,7091],["MAD-BUH",7453,10348],["MAD-GYE",7066,5907],["BCN-LIM",6972,5944],["BCN-LIS",6863,5891],["MAD-LAX",6803,5491],["MAD-ACE",6639,12072],["MAD-MUC",6595,6589],["LPA-MAD",6464,6423],["PMI-MAD",6443,8722],["MAD-FRA",6437,6162],["BCN-IST",6359,6863],["MAD-PMI",6329,7323],["TCI-MAD",5937,6933]],"top_destinations":[["MAD",142829,187708],["LON",115239,121913],["NYC",104343,95713],["PAR",94770,95406],["BCN",94504,129752],["ROM",60362,56594],["TCI",49638,65097],["BUE",45029,35730],["LIM",40472,29031],["AMS",38227,40874],["BKK",37872,48243],["BER",34956,38663],["MIA",32743,33873],["LPA",32664,59007],["LIS",32562,30425],["PMI",30325,46259],["BRU",29455,26457],["IST",29202,38286],["AGP",25060,30940],["MIL",24627,35344],["RAK",24535,24158],["PRG",23722,30068],["MEX",21681,19587],["SVQ",21672,29604],["SAO",21346,15752],["SCL",21303,14972],["BOG",20084,15447],["LAX",19417,18186],["ACE",19374,35117],["MUC",19287,20955],["HAV",18815,14133],["FRA",17802,19694],["VLC",17610,20342],["BIO",17526,21419],["DXB",16689,17527],["SDQ",16570,14154],["VIE",16032,18963],["RIO",14540,11043],["GYE",14452,12516],["OPO",14299,14905],["VCE",14262,18807],["BUH",14227,18287],["TYO",14114,10508],["UIO",13989,12020],["DUB",13032,18366],["FUE",12911,28598],["GVA",12721,16139],["IBZ",12717,23316],["CUN",12625,11634],["MOW",12611,12712]],"advance_purchase":[356909,311928,259554,195997,150085,111008,94343,84628,76143,69181,58549,51997,45566,35915,35740,44470,42642,43967,40499,28344,20635,17665,15263,15246,16332,19111,22807,21415,20724,19441,160380]}]}

# %%
onds = myperfjson['search_by_search_period'][0]['top_onds']
print onds[1]
if onds[1][0][0]=='M':
    print onds[1][0]
else:
    print onds[1][0][0]
# Out:
# ['MAD-LON', 32772, 36962]
# MAD-LON

# %%
# add the difference, which might be more interesting...
print "O&D, Searches for Year 2013, Year Searches for 2012, Difference"
for ond in onds:
    ondLabel = ond[0]
    nbSearchesYN = ond[1]
    nbSearchesYNm1 = ond[2]
    print ondLabel, ",", nbSearchesYN, ",", nbSearchesYNm1, ",", (nbSearchesYN-nbSearchesYNm1)
# Out:
# O&D, Searches for Year 2013, Year Searches for 2012, Difference
# MAD-NYC , 45426 , 44735 , 691
# MAD-LON , 32772 , 36962 , -4190
# MAD-PAR , 31422 , 28431 , 2991
# BCN-NYC , 23396 , 19974 , 3422
# MAD-LIM , 22431 , 15967 , 6464
# MAD-ROM , 21847 , 19966 , 1881
# BCN-LON , 20107 , 21889 , -1782
# BCN-MAD , 18762 , 25028 , -6266
# BCN-PAR , 18285 , 19923 , -1638
# MAD-BCN , 18282 , 18940 , -658
# MAD-BUE , 17081 , 17481 , -400
# MAD-TCI , 15918 , 20030 , -4112
# MAD-BKK , 15470 , 12605 , 2865
# MAD-AMS , 13235 , 15079 , -1844
# MAD-MIA , 12883 , 12638 , 245
# BCN-ROM , 12122 , 11710 , 412
# MAD-BER , 11457 , 12016 , -559
# MAD-BRU , 11412 , 9735 , 1677
# MAD-LPA , 10742 , 20857 , -10115
# MAD-RAK , 10701 , 9326 , 1375
# MAD-LIS , 10467 , 10059 , 408
# MAD-SCL , 9774 , 7281 , 2493
# BCN-BUE , 9738 , 8274 , 1464
# BCN-BKK , 9463 , 6655 , 2808
# BCN-AMS , 9060 , 9884 , -824
# MAD-MIL , 9036 , 13365 , -4329
# AGP-LON , 8773 , 7269 , 1504
# MAD-MEX , 8721 , 9854 , -1133
# MAD-PRG , 8521 , 10030 , -1509
# MAD-IST , 8469 , 10568 , -2099
# MAD-HAV , 8454 , 6238 , 2216
# MAD-BOG , 8435 , 7222 , 1213
# BCN-BER , 8301 , 7887 , 414
# MAD-SAO , 8295 , 5679 , 2616
# BCN-TCI , 8245 , 12463 , -4218
# MAD-SDQ , 8079 , 7858 , 221
# MAD-UIO , 7731 , 7091 , 640
# MAD-BUH , 7453 , 10348 , -2895
# MAD-GYE , 7066 , 5907 , 1159
# BCN-LIM , 6972 , 5944 , 1028
# BCN-LIS , 6863 , 5891 , 972
# MAD-LAX , 6803 , 5491 , 1312
# MAD-ACE , 6639 , 12072 , -5433
# MAD-MUC , 6595 , 6589 , 6
# LPA-MAD , 6464 , 6423 , 41
# PMI-MAD , 6443 , 8722 , -2279
# MAD-FRA , 6437 , 6162 , 275
# BCN-IST , 6359 , 6863 , -504
# MAD-PMI , 6329 , 7323 , -994
# TCI-MAD , 5937 , 6933 , -996

# %%
# See total passengers from/to MAD and BCN

FROM_MAD = [[x[0],x[1]-x[2]] for x in onds if x[0][0:3]=='MAD']
TO_MAD = [[x[0],x[1]-x[2]] for x in onds if x[0][4:7]=='MAD']
FT_MAD = [[x[0],x[1]-x[2]] for x in onds if (x[0][0:3]=='MAD') | (x[0][4:7]=='MAD')]

if len([x for x in FT_MAD]) != (len([x for x in FROM_MAD])+len([x for x in TO_MAD])):
    print 'there must be an error in MAD flights'

FROM_BCN = [[x[0],x[1]-x[2]] for x in onds if x[0][0:3]=='BCN']
TO_BCN = [[x[0],x[1]-x[2]] for x in onds if x[0][4:7]=='BCN']
FT_BCN = [[x[0],x[1]-x[2]] for x in onds if (x[0][0:3]=='BCN') | (x[0][4:7]=='BCN')]

if len([x for x in FT_BCN]) != (len([x for x in FROM_BCN])+len([x for x in TO_BCN])):
    print 'there must be an error in BCN flights'

if 0:
    print '\n----------- MAD flights----------\n'
    print FROM_MAD, '\n\n\n', TO_MAD, '\n\n\n', FT_MAD

    print '\n----------- BCN flights----------\n'
    print FROM_BCN, '\n\n\n', TO_BCN, '\n\n\n', FT_BCN

# print TO_BCN
import numpy as np

flags = ['MAD','BCN']
for flag in flags:
    print '\n ***********Changes in',flag,'flights*********\n'
    
    # TOTAL CHANGES
    print 'Percentage change in',flag,'flights'
    
    # total
    out = np.sum([x[1]-x[2] for x in onds if (x[0][0:3]==flag) | (x[0][4:7]==flag)])
    out_12 = np.sum([x[2] for x in onds if (x[0][0:3]==flag) | (x[0][4:7]==flag)])
    print 'Total:', out, '(', float(1000*out/out_12)/float(10),') %'
    
    # outcoming
    out = np.sum([x[1]-x[2] for x in onds if (x[0][0:3]==flag)])
    out_12 = np.sum([x[2] for x in onds if x[0][0:3]==flag])
    print '\tOutcoming:', out, '(', int(1000*out/out_12)/float(10),') %'
    
    #incoming
    out = np.sum([x[1]-x[2] for x in onds if (x[0][4:7]==flag)])
    out_12 = np.sum([x[2] for x in onds if x[0][4:7]==flag])
    print '\tIncoming:', out, '(', int(1000*out/out_12)/float(10),') %'
    
    # CHANGES IN CONNECTIONS FROM AVERAGE
    print '\nMean percentage change in',flag,'connections'
    
    #total
    out = [float(x[1]-x[2])/float(x[2]) for x in onds if (x[0][0:3]==flag) | (x[0][4:7]==flag)]
    print 'Total:', int(np.mean(out)*1000)/float(10), '% (std:', int(1000*np.std(out))/float(10),'%)'
    
    # incoming
    out = [float(x[1]-x[2])/float(x[2]) for x in onds if x[0][0:3]==flag]
    ind = [x[0] for x in onds if x[0][0:3]==flag]
    print '\tOutcoming:', int(np.mean(out)*1000)/float(10),'%',\
        '(max.:',int(max((out))*1000)/float(10),\
            '% in',ind[out.index(max((out)))],'connection; ',\
          'min.: ',int(min((out))*1000)/float(10),\
            '% in',ind[out.index(min((out)))],'flight)'
            
    # outcoming
    out = [float(x[1]-x[2])/float(x[2]) for x in onds if x[0][4:7]==flag]
    ind = [x[0] for x in onds if x[0][4:7]==flag]
    print '\tIncoming:', int(np.mean(out)*1000)/float(10),'%',\
        '(max.:',int(max((out))*1000)/float(10),\
            '% in',ind[out.index(max((out)))],'connection; ',\
          'min.: ',int(min((out))*1000)/float(10),\
            '% in',ind[out.index(min((out)))],'flight)'
# Out:
#  ***********Changes in MAD flights*********
#
# Percentage change in MAD flights
# Total: -19022 ( -3.9 ) %
# 	Outcoming: -9522 ( -2.2 ) %
# 	Incoming: -9500 ( -20.2 ) %
#
# Mean percentage change in MAD connections
# Total: -0.4 % (std: 22.1 %)
# 	Outcoming: 1.4 % (max.: 46.0 % in MAD-SAO connection;  min.:  -48.4 % in MAD-LPA flight)
# 	Incoming: -16.2 % (max.: 0.6 % in LPA-MAD connection;  min.:  -26.1 % in PMI-MAD flight)
#
#  ***********Changes in BCN flights*********
#
# Percentage change in BCN flights
# Total: -5370 ( -3.0 ) %
# 	Outcoming: -4712 ( -3.0 ) %
# 	Incoming: -658 ( -3.5 ) %
#
# Mean percentage change in BCN connections
# Total: 1.7 % (std: 18.8 %)
# 	Outcoming: 2.2 % (max.: 42.1 % in BCN-BKK connection;  min.:  -33.8 % in BCN-TCI flight)
# 	Incoming: -3.4 % (max.: -3.4 % in MAD-BCN connection;  min.:  -3.4 % in MAD-BCN flight)
