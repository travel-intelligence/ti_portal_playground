# %%
import json;

# %%
myperfjson = {"performances":[{"id":"GA_2013-10_city","carrier":"GA","month":"2013-10","level":"city","legs":[{"orig":"JKT","dest":"DPS","capash":44.0,"trafsh":34.0,"freqsh":36.0},{"orig":"DPS","dest":"JKT","capash":44.0,"trafsh":35.0,"freqsh":36.0},{"orig":"JKT","dest":"SUB","capash":27.0,"trafsh":30.0,"freqsh":27.0},{"orig":"SUB","dest":"JKT","capash":27.0,"trafsh":23.0,"freqsh":27.0},{"orig":"UPG","dest":"JKT","capash":24.0,"trafsh":25.0,"freqsh":25.0},{"orig":"JKT","dest":"UPG","capash":29.0,"trafsh":25.0,"freqsh":29.0},{"orig":"JKT","dest":"SIN","capash":19.0,"trafsh":15.0,"freqsh":21.0},{"orig":"SIN","dest":"JKT","capash":19.0,"trafsh":15.0,"freqsh":20.0},{"orig":"PLM","dest":"JKT","capash":40.0,"trafsh":33.0,"freqsh":40.0},{"orig":"JKT","dest":"PLM","capash":40.0,"trafsh":36.0,"freqsh":40.0},{"orig":"JOG","dest":"JKT","capash":34.0,"trafsh":31.0,"freqsh":34.0},{"orig":"JKT","dest":"JOG","capash":34.0,"trafsh":35.0,"freqsh":34.0},{"orig":"JKT","dest":"MES","capash":24.0,"trafsh":21.0,"freqsh":24.0},{"orig":"MES","dest":"JKT","capash":24.0,"trafsh":19.0,"freqsh":24.0},{"orig":"SRG","dest":"JKT","capash":40.0,"trafsh":32.0,"freqsh":40.0},{"orig":"JKT","dest":"SRG","capash":40.0,"trafsh":35.0,"freqsh":40.0},{"orig":"JKT","dest":"BPN","capash":36.0,"trafsh":31.0,"freqsh":38.0},{"orig":"BPN","dest":"JKT","capash":36.0,"trafsh":32.0,"freqsh":38.0},{"orig":"PKU","dest":"JKT","capash":36.0,"trafsh":21.0,"freqsh":37.0},{"orig":"JKT","dest":"PKU","capash":36.0,"trafsh":21.0,"freqsh":37.0},{"orig":"JKT","dest":"PNK","capash":31.0,"trafsh":30.0,"freqsh":35.0},{"orig":"PNK","dest":"JKT","capash":31.0,"trafsh":29.0,"freqsh":35.0},{"orig":"PDG","dest":"JKT","capash":30.0,"trafsh":20.0,"freqsh":31.0},{"orig":"JKT","dest":"PDG","capash":30.0,"trafsh":24.0,"freqsh":31.0},{"orig":"BDJ","dest":"JKT","capash":34.0,"trafsh":33.0,"freqsh":35.0},{"orig":"JKT","dest":"BDJ","capash":34.0,"trafsh":34.0,"freqsh":35.0},{"orig":"TKG","dest":"JKT","capash":43.0,"trafsh":37.0,"freqsh":38.0},{"orig":"JKT","dest":"TKG","capash":43.0,"trafsh":37.0,"freqsh":38.0},{"orig":"SOC","dest":"JKT","capash":34.0,"trafsh":25.0,"freqsh":34.0},{"orig":"BTH","dest":"JKT","capash":33.0,"trafsh":29.0,"freqsh":34.0},{"orig":"JKT","dest":"BTH","capash":33.0,"trafsh":30.0,"freqsh":34.0},{"orig":"JKT","dest":"SOC","capash":34.0,"trafsh":26.0,"freqsh":34.0},{"orig":"TYO","dest":"DPS","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"DPS","dest":"TYO","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"BKK","dest":"JKT","capash":35.0,"trafsh":38.0,"freqsh":38.0},{"orig":"JKT","dest":"BKK","capash":35.0,"trafsh":40.0,"freqsh":38.0},{"orig":"JKT","dest":"DJB","capash":30.0,"trafsh":22.0,"freqsh":30.0},{"orig":"LOP","dest":"JKT","capash":35.0,"trafsh":28.0,"freqsh":38.0},{"orig":"JKT","dest":"LOP","capash":35.0,"trafsh":29.0,"freqsh":38.0},{"orig":"DJB","dest":"JKT","capash":30.0,"trafsh":21.0,"freqsh":30.0},{"orig":"HKG","dest":"JKT","capash":21.0,"trafsh":22.0,"freqsh":28.0},{"orig":"JKT","dest":"HKG","capash":20.0,"trafsh":22.0,"freqsh":27.0},{"orig":"JOG","dest":"DPS","capash":40.0,"trafsh":35.0,"freqsh":41.0},{"orig":"DPS","dest":"JOG","capash":39.0,"trafsh":35.0,"freqsh":41.0},{"orig":"DPS","dest":"MEL","capash":49.0,"trafsh":49.0,"freqsh":36.0},{"orig":"MEL","dest":"DPS","capash":49.0,"trafsh":49.0,"freqsh":36.0},{"orig":"SEL","dest":"JKT","capash":32.0,"trafsh":34.0,"freqsh":33.0},{"orig":"JKT","dest":"SEL","capash":32.0,"trafsh":35.0,"freqsh":33.0},{"orig":"MDC","dest":"JKT","capash":49.0,"trafsh":35.0,"freqsh":52.0},{"orig":"JKT","dest":"MDC","capash":49.0,"trafsh":33.0,"freqsh":52.0},{"orig":"JKT","dest":"BJS","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"JED","dest":"JKT","capash":24.0,"trafsh":45.0,"freqsh":26.0},{"orig":"JKT","dest":"JED","capash":24.0,"trafsh":42.0,"freqsh":27.0},{"orig":"BJS","dest":"JKT","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"PKY","dest":"JKT","capash":39.0,"trafsh":28.0,"freqsh":40.0},{"orig":"KUL","dest":"JKT","capash":8.0,"trafsh":6.0,"freqsh":9.0},{"orig":"JKT","dest":"PGK","capash":19.0,"trafsh":11.0,"freqsh":17.0},{"orig":"DPS","dest":"PER","capash":22.0,"trafsh":30.0,"freqsh":21.0},{"orig":"PGK","dest":"JKT","capash":19.0,"trafsh":11.0,"freqsh":17.0},{"orig":"JKT","dest":"PKY","capash":39.0,"trafsh":25.0,"freqsh":40.0},{"orig":"PER","dest":"DPS","capash":22.0,"trafsh":28.0,"freqsh":21.0},{"orig":"JKT","dest":"KUL","capash":8.0,"trafsh":6.0,"freqsh":9.0},{"orig":"DPS","dest":"OSA","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"OSA","dest":"DPS","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"JKT","dest":"SHA","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"SHA","dest":"JKT","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"TYO","dest":"JKT","capash":33.0,"trafsh":32.0,"freqsh":33.0},{"orig":"JKT","dest":"TYO","capash":33.0,"trafsh":31.0,"freqsh":33.0},{"orig":"SUB","dest":"DPS","capash":18.0,"trafsh":29.0,"freqsh":26.0},{"orig":"DPS","dest":"SUB","capash":18.0,"trafsh":29.0,"freqsh":26.0},{"orig":"SYD","dest":"DPS","capash":42.0,"trafsh":44.0,"freqsh":35.0},{"orig":"DPS","dest":"SYD","capash":42.0,"trafsh":48.0,"freqsh":36.0},{"orig":"JKT","dest":"CAN","capash":64.0,"trafsh":42.0,"freqsh":50.0},{"orig":"CAN","dest":"JKT","capash":63.0,"trafsh":43.0,"freqsh":50.0},{"orig":"SIN","dest":"DPS","capash":8.0,"trafsh":9.0,"freqsh":11.0},{"orig":"DPS","dest":"SIN","capash":8.0,"trafsh":11.0,"freqsh":11.0},{"orig":"DPS","dest":"SEL","capash":32.0,"trafsh":35.0,"freqsh":32.0},{"orig":"SEL","dest":"DPS","capash":31.0,"trafsh":36.0,"freqsh":32.0},{"orig":"JKT","dest":"AUH","capash":35.0,"trafsh":26.0,"freqsh":42.0},{"orig":"AMS","dest":"AUH","capash":29.0,"trafsh":21.0,"freqsh":30.0},{"orig":"AUH","dest":"JKT","capash":35.0,"trafsh":29.0,"freqsh":42.0},{"orig":"JKT","dest":"MLG","capash":38.0,"trafsh":38.0,"freqsh":40.0},{"orig":"MLG","dest":"JKT","capash":38.0,"trafsh":38.0,"freqsh":40.0},{"orig":"MEL","dest":"JKT","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"JKT","dest":"MEL","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"AUH","dest":"AMS","capash":26.0,"trafsh":19.0,"freqsh":26.0},{"orig":"JKT","dest":"SYD","capash":44.0,"trafsh":48.0,"freqsh":51.0},{"orig":"GTO","dest":"UPG","capash":25.0,"trafsh":21.0,"freqsh":40.0},{"orig":"UPG","dest":"KDI","capash":19.0,"trafsh":24.0,"freqsh":21.0},{"orig":"JKT","dest":"AMQ","capash":47.0,"trafsh":29.0,"freqsh":50.0},{"orig":"BTJ","dest":"JKT","capash":47.0,"trafsh":32.0,"freqsh":50.0},{"orig":"DJJ","dest":"TIM","capash":100.0,"trafsh":47.0,"freqsh":100.0},{"orig":"DJJ","dest":"UPG","capash":16.0,"trafsh":11.0,"freqsh":17.0},{"orig":"JKT","dest":"TPE","capash":21.0,"trafsh":25.0,"freqsh":33.0},{"orig":"BNE","dest":"DPS","capash":45.0,"trafsh":50.0,"freqsh":45.0},{"orig":"UPG","dest":"DJJ","capash":16.0,"trafsh":14.0,"freqsh":18.0},{"orig":"TPE","dest":"JKT","capash":21.0,"trafsh":25.0,"freqsh":33.0},{"orig":"UPG","dest":"SUB","capash":5.0,"trafsh":8.0,"freqsh":9.0},{"orig":"UPG","dest":"GTO","capash":25.0,"trafsh":21.0,"freqsh":40.0},{"orig":"BIK","dest":"UPG","capash":77.0,"trafsh":59.0,"freqsh":70.0},{"orig":"UPG","dest":"PLW","capash":20.0,"trafsh":21.0,"freqsh":33.0},{"orig":"SUB","dest":"BPN","capash":5.0,"trafsh":9.0,"freqsh":10.0},{"orig":"DPS","dest":"BNE","capash":44.0,"trafsh":50.0,"freqsh":44.0},{"orig":"BPN","dest":"SUB","capash":5.0,"trafsh":9.0,"freqsh":10.0},{"orig":"UPG","dest":"AMQ","capash":24.0,"trafsh":14.0,"freqsh":26.0},{"orig":"AMQ","dest":"UPG","capash":18.0,"trafsh":14.0,"freqsh":20.0},{"orig":"JKT","dest":"BTJ","capash":47.0,"trafsh":38.0,"freqsh":50.0},{"orig":"KDI","dest":"UPG","capash":16.0,"trafsh":22.0,"freqsh":21.0},{"orig":"BTJ","dest":"MES","capash":19.0,"trafsh":32.0,"freqsh":43.0},{"orig":"SUB","dest":"UPG","capash":5.0,"trafsh":7.0,"freqsh":9.0},{"orig":"AMQ","dest":"JKT","capash":47.0,"trafsh":32.0,"freqsh":50.0},{"orig":"MES","dest":"BTJ","capash":19.0,"trafsh":33.0,"freqsh":43.0},{"orig":"DJJ","dest":"BIK","capash":77.0,"trafsh":48.0,"freqsh":70.0},{"orig":"SUB","dest":"BDO","capash":25.0,"trafsh":15.0,"freqsh":25.0},{"orig":"BDO","dest":"SUB","capash":25.0,"trafsh":14.0,"freqsh":25.0},{"orig":"PLW","dest":"UPG","capash":17.0,"trafsh":20.0,"freqsh":29.0},{"orig":"DPS","dest":"HKG","capash":13.0,"trafsh":16.0,"freqsh":24.0},{"orig":"HKG","dest":"DPS","capash":13.0,"trafsh":16.0,"freqsh":23.0},{"orig":"SYD","dest":"JKT","capash":42.0,"trafsh":49.0,"freqsh":50.0},{"orig":"DPS","dest":"BDO","capash":12.0,"trafsh":9.0,"freqsh":11.0},{"orig":"DPS","dest":"UPG","capash":22.0,"trafsh":24.0,"freqsh":38.0},{"orig":"DPS","dest":"LOP","capash":29.0,"trafsh":14.0,"freqsh":13.0},{"orig":"UPG","dest":"DPS","capash":22.0,"trafsh":24.0,"freqsh":38.0},{"orig":"BDO","dest":"DPS","capash":10.0,"trafsh":10.0,"freqsh":10.0},{"orig":"LOP","dest":"DPS","capash":29.0,"trafsh":14.0,"freqsh":13.0},{"orig":"TIM","dest":"DPS","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"KOE","dest":"DPS","capash":47.0,"trafsh":36.0,"freqsh":51.0},{"orig":"DPS","dest":"KOE","capash":100.0,"trafsh":62.0,"freqsh":100.0},{"orig":"MDC","dest":"UPG","capash":17.0,"trafsh":13.0,"freqsh":35.0},{"orig":"UPG","dest":"MDC","capash":17.0,"trafsh":14.0,"freqsh":35.0},{"orig":"PER","dest":"JKT","capash":68.0,"trafsh":70.0,"freqsh":68.0},{"orig":"JKT","dest":"PER","capash":66.0,"trafsh":73.0,"freqsh":66.0},{"orig":"JKT","dest":"BKS","capash":11.0,"trafsh":7.0,"freqsh":14.0},{"orig":"JKT","dest":"TJQ","capash":20.0,"trafsh":21.0,"freqsh":20.0},{"orig":"TJQ","dest":"JKT","capash":20.0,"trafsh":21.0,"freqsh":20.0},{"orig":"BKS","dest":"JKT","capash":11.0,"trafsh":9.0,"freqsh":14.0},{"orig":"TTE","dest":"JKT","capash":53.0,"trafsh":67.0,"freqsh":49.0},{"orig":"JKT","dest":"TTE","capash":53.0,"trafsh":67.0,"freqsh":49.0},{"orig":"TNJ","dest":"JKT","capash":28.0,"trafsh":26.0,"freqsh":33.0},{"orig":"JKT","dest":"TNJ","capash":28.0,"trafsh":24.0,"freqsh":33.0},{"orig":"SIN","dest":"SUB","capash":6.0,"trafsh":8.0,"freqsh":8.0},{"orig":"SUB","dest":"SIN","capash":6.0,"trafsh":8.0,"freqsh":8.0},{"orig":"BPN","dest":"SIN","capash":40.0,"trafsh":43.0,"freqsh":39.0},{"orig":"SIN","dest":"BPN","capash":40.0,"trafsh":44.0,"freqsh":39.0},{"orig":"BPN","dest":"UPG","capash":10.0,"trafsh":18.0,"freqsh":24.0},{"orig":"UPG","dest":"BPN","capash":10.0,"trafsh":18.0,"freqsh":24.0},{"orig":"TIM","dest":"DJJ","capash":100.0,"trafsh":46.0,"freqsh":100.0},{"orig":"DPS","dest":"TIM","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"BIK","dest":"DJJ","capash":49.0,"trafsh":48.0,"freqsh":41.0},{"orig":"UPG","dest":"BIK","capash":49.0,"trafsh":57.0,"freqsh":41.0},{"orig":"PKY","dest":"BDJ","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"BDJ","dest":"PKY","capash":100.0,"trafsh":100.0,"freqsh":100.0},{"orig":"KOE","dest":"SUB","capash":3.0,"trafsh":12.0,"freqsh":18.0},{"orig":"SUB","dest":"KOE","capash":3.0,"trafsh":12.0,"freqsh":18.0},{"orig":"TIM","dest":"UPG","capash":100.0,"trafsh":13.0,"freqsh":100.0},{"orig":"PEN","dest":"MES","capash":0.0,"trafsh":6.0,"freqsh":0.0},{"orig":"MKW","dest":"DJJ","capash":0.0,"trafsh":15.0,"freqsh":0.0},{"orig":"DJJ","dest":"DPS","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"JKT","dest":"TIM","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"BTH","dest":"PKU","capash":0.0,"trafsh":14.0,"freqsh":0.0},{"orig":"BDJ","dest":"SUB","capash":0.0,"trafsh":5.0,"freqsh":0.0},{"orig":"MES","dest":"PEN","capash":0.0,"trafsh":6.0,"freqsh":0.0},{"orig":"CIW","dest":"BGI","capash":0.0,"trafsh":50.0,"freqsh":0.0},{"orig":"PLW","dest":"JKT","capash":0.0,"trafsh":6.0,"freqsh":0.0},{"orig":"SRG","dest":"DPS","capash":0.0,"trafsh":21.0,"freqsh":0.0},{"orig":"SOQ","dest":"MKW","capash":0.0,"trafsh":12.0,"freqsh":0.0},{"orig":"DPS","dest":"SRG","capash":0.0,"trafsh":21.0,"freqsh":0.0},{"orig":"PDG","dest":"MES","capash":0.0,"trafsh":18.0,"freqsh":0.0},{"orig":"TRK","dest":"BPN","capash":0.0,"trafsh":4.0,"freqsh":0.0},{"orig":"MKW","dest":"SOQ","capash":0.0,"trafsh":12.0,"freqsh":0.0},{"orig":"MES","dest":"PKU","capash":0.0,"trafsh":14.0,"freqsh":0.0},{"orig":"LOP","dest":"SUB","capash":0.0,"trafsh":8.0,"freqsh":0.0},{"orig":"MDC","dest":"BPN","capash":0.0,"trafsh":36.0,"freqsh":0.0},{"orig":"BPN","dest":"TRK","capash":0.0,"trafsh":4.0,"freqsh":0.0},{"orig":"UPG","dest":"TTE","capash":0.0,"trafsh":44.0,"freqsh":0.0},{"orig":"SOQ","dest":"UPG","capash":0.0,"trafsh":3.0,"freqsh":0.0},{"orig":"BGI","dest":"CIW","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"SRG","dest":"SUB","capash":0.0,"trafsh":18.0,"freqsh":0.0},{"orig":"MES","dest":"PLM","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"TTE","dest":"MDC","capash":0.0,"trafsh":29.0,"freqsh":0.0},{"orig":"DJJ","dest":"MKW","capash":0.0,"trafsh":15.0,"freqsh":0.0},{"orig":"TTE","dest":"UPG","capash":0.0,"trafsh":37.0,"freqsh":0.0},{"orig":"MES","dest":"PDG","capash":0.0,"trafsh":17.0,"freqsh":0.0},{"orig":"BPN","dest":"BEJ","capash":0.0,"trafsh":27.0,"freqsh":0.0},{"orig":"PDG","dest":"PKU","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"SUB","dest":"BDJ","capash":0.0,"trafsh":5.0,"freqsh":0.0},{"orig":"BPN","dest":"BDJ","capash":0.0,"trafsh":14.0,"freqsh":0.0},{"orig":"BPN","dest":"MDC","capash":0.0,"trafsh":35.0,"freqsh":0.0},{"orig":"LOP","dest":"UPG","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"SUB","dest":"SRG","capash":0.0,"trafsh":19.0,"freqsh":0.0},{"orig":"UPG","dest":"SOQ","capash":0.0,"trafsh":6.0,"freqsh":0.0},{"orig":"PLM","dest":"MES","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"PKU","dest":"MES","capash":0.0,"trafsh":14.0,"freqsh":0.0},{"orig":"UPG","dest":"LOP","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"BTH","dest":"MES","capash":0.0,"trafsh":18.0,"freqsh":0.0},{"orig":"BPN","dest":"JOG","capash":0.0,"trafsh":11.0,"freqsh":0.0},{"orig":"BDJ","dest":"BPN","capash":0.0,"trafsh":13.0,"freqsh":0.0},{"orig":"JOG","dest":"BPN","capash":0.0,"trafsh":11.0,"freqsh":0.0},{"orig":"PKU","dest":"BTH","capash":0.0,"trafsh":15.0,"freqsh":0.0},{"orig":"MES","dest":"BTH","capash":0.0,"trafsh":19.0,"freqsh":0.0},{"orig":"MDC","dest":"TTE","capash":0.0,"trafsh":34.0,"freqsh":0.0},{"orig":"BEJ","dest":"BPN","capash":0.0,"trafsh":28.0,"freqsh":0.0},{"orig":"PKU","dest":"PDG","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"JKT","dest":"AMS","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"BGI","dest":"BQU","capash":0.0,"trafsh":100.0,"freqsh":0.0},{"orig":"SUB","dest":"LOP","capash":0.0,"trafsh":8.0,"freqsh":0.0},{"orig":"JKT","dest":"PLW","capash":0.0,"trafsh":5.0,"freqsh":0.0}]}]}

# %%
myperfjson
# Out:
# {'performances': [{'carrier': 'GA',
#    'id': 'GA_2013-10_city',
#    'legs': [{'capash': 44.0,
#      'dest': 'DPS',
#      'freqsh': 36.0,
#      'orig': 'JKT',
#      'trafsh': 34.0},
#     {'capash': 44.0,
#      'dest': 'JKT',
#      'freqsh': 36.0,
#      'orig': 'DPS',
#      'trafsh': 35.0},
#     {'capash': 27.0,
#      'dest': 'SUB',
#      'freqsh': 27.0,
#      'orig': 'JKT',
#      'trafsh': 30.0},
#     {'capash': 27.0,
#      'dest': 'JKT',
#      'freqsh': 27.0,
#      'orig': 'SUB',
#      'trafsh': 23.0},
#     {'capash': 24.0,
#      'dest': 'JKT',
#      'freqsh': 25.0,
#      'orig': 'UPG',
#      'trafsh': 25.0},
#     {'capash': 29.0,
#      'dest': 'UPG',
#      'freqsh': 29.0,
#      'orig': 'JKT',
#      'trafsh': 25.0},
#     {'capash': 19.0,
#      'dest': 'SIN',
#      'freqsh': 21.0,
#      'orig': 'JKT',
#      'trafsh': 15.0},
#     {'capash': 19.0,
#      'dest': 'JKT',
#      'freqsh': 20.0,
#      'orig': 'SIN',
#      'trafsh': 15.0},
# ...

# %%
points = myperfjson['performances'][0]['legs']

# %%
for point in points:
    capash = point['capash']
    trafsh = point['trafsh']
    orig = point['orig']
    dest = point['dest']
    if (capash - trafsh)/max(0.1, capash) > 0.30:
        print orig, ",", dest, ",", capash, ",", trafsh
# Out:
# PKU , JKT , 36.0 , 21.0
# JKT , PKU , 36.0 , 21.0
# PDG , JKT , 30.0 , 20.0
# JKT , MDC , 49.0 , 33.0
# JKT , PGK , 19.0 , 11.0
# PGK , JKT , 19.0 , 11.0
# JKT , PKY , 39.0 , 25.0
# JKT , CAN , 64.0 , 42.0
# CAN , JKT , 63.0 , 43.0
# JKT , AMQ , 47.0 , 29.0
# BTJ , JKT , 47.0 , 32.0
# DJJ , TIM , 100.0 , 47.0
# DJJ , UPG , 16.0 , 11.0
# UPG , AMQ , 24.0 , 14.0
# AMQ , JKT , 47.0 , 32.0
# DJJ , BIK , 77.0 , 48.0
# SUB , BDO , 25.0 , 15.0
# BDO , SUB , 25.0 , 14.0
# DPS , LOP , 29.0 , 14.0
# LOP , DPS , 29.0 , 14.0
# DPS , KOE , 100.0 , 62.0
# JKT , BKS , 11.0 , 7.0
# TIM , DJJ , 100.0 , 46.0
# TIM , UPG , 100.0 , 13.0
